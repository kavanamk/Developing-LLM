# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
# Load CSV files
df_accepted = pd.read_csv("/Users/kavanamanvi/Desktop/creditRisk/accepted.csv")
# Out:
# /var/folders/b2/s6cq43q964gcjk0fp440gx_h0000gn/T/ipykernel_38460/1644585130.py:2: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_accepted = pd.read_csv("/Users/kavanamanvi/Desktop/creditRisk/accepted.csv")

# %%
df_rejected = pd.read_csv("/Users/kavanamanvi/Desktop/creditRisk/rejected.csv")

# %% [markdown]
# #### List of column names

# %%
df_accepted.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=151)

# %%
df_rejected = df_rejected.rename(columns={
    "Amount Requested": "LoanAmount",
    "Application Date": "Date",
    "Loan Title": "purpose",
    "Risk_Score": "riskScore",
    "Debt-To-Income Ratio": "debtToIncomeRatio",
    "Zip Code": "zipCode",
    "State": "state",
    "Employment Length": "employmentLength",
    "Policy Code": "policyCode"
})

# %%
df_rejected = df_rejected.drop(columns=["riskScore"])

# %%
df_rejected.columns
# Out:
# Index(['LoanAmount', 'Date', 'purpose', 'debtToIncomeRatio', 'zipCode',
#        'state', 'employmentLength', 'policyCode', 'target'],
#       dtype='object')

# %% [markdown]
# #### Common Columns

# %%
df_accepted = df_accepted.rename(columns={
    "loan_amnt": "LoanAmount",
    "issue_d": "Date",
    "purpose": "purpose",
    "dti": "debtToIncomeRatio",
    "zip_code": "zipCode",
    "addr_state": "state",
    "emp_length": "employmentLength",
    "policy_code": "policyCode"
})

# %%
#only keep common columns

rej_cols = [
    "LoanAmount",
    "Date",
    "purpose",
    "debtToIncomeRatio",
    "zipCode",
    "state",
    "employmentLength",
    "policyCode"
]

df_accepted = df_accepted[rej_cols]

# %%
# accepted = 0
df_accepted["target"] = 0

# rejected = 1
df_rejected["target"] = 1

# %%
df_accepted.head()
# Out:
#    LoanAmount      Date             purpose  debtToIncomeRatio zipCode state  \
# 0      3600.0  Dec-2015  debt_consolidation               5.91   190xx    PA
# 1     24700.0  Dec-2015      small_business              16.06   577xx    SD
# 2     20000.0  Dec-2015    home_improvement              10.78   605xx    IL
# 3     35000.0  Dec-2015  debt_consolidation              17.06   076xx    NJ
# 4     10400.0  Dec-2015      major_purchase              25.37   174xx    PA
#
#   employmentLength  policyCode  target
# 0        10+ years         1.0       0
# 1        10+ years         1.0       0
# 2        10+ years         1.0       0
# 3        10+ years         1.0       0
# 4          3 years         1.0       0

# %%
df_rejected.head()
# Out:
#    LoanAmount        Date                           purpose debtToIncomeRatio  \
# 0      1000.0  2007-05-26  Wedding Covered but No Honeymoon               10%
# 1      1000.0  2007-05-26                Consolidating Debt               10%
# 2     11000.0  2007-05-27       Want to consolidate my debt               10%
# 3      6000.0  2007-05-27                           waksman            38.64%
# 4      1500.0  2007-05-27                            mdrigo             9.43%
#
#   zipCode state employmentLength  policyCode  target
# 0   481xx    NM          4 years         0.0       1
# 1   010xx    MA         < 1 year         0.0       1
# 2   212xx    MD           1 year         0.0       1
# 3   017xx    MA         < 1 year         0.0       1
# 4   209xx    MD         < 1 year         0.0       1

# %% [markdown]
# ### Merge Both datasets

# %%
df_merged = pd.concat(
    [df_accepted_aligned, df_rejected],
    ignore_index=True
)

# Shuffle rows
df = df_merged.sample(
    frac=1,
    random_state=42
).reset_index(drop=True)
